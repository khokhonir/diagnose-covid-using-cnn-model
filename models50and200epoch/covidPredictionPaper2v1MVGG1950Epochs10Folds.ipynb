# %%
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import cv2
from datetime import datetime

# Get the current time
now = datetime.now()
print("Start Time =", now)

# Define size to which images are to be resized
IMAGE_SIZE = [224, 224]

# Training configurations
epochs = 50     # adjust as needed
batch_size = 32
n_splits = 10    # 2–20 folds

# Paths
covid_path = '/home/CT_COVID'
noncovid_path = '/home/CT_NonCOVID'

# Load files
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

print("COVID images:", len(covid_files))
print("Non-COVID images:", len(noncovid_files))

# --- Preprocessing function ---
def preprocess_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    contrast_enhanced = clahe.apply(gray)
    contrast_enhanced_rgb = cv2.cvtColor(contrast_enhanced, cv2.COLOR_GRAY2RGB)
    denoised_image = cv2.GaussianBlur(contrast_enhanced_rgb, (3, 3), 0)
    return denoised_image

# Load COVID images
covid_images, covid_labels = [], []
for f in covid_files:
    img = cv2.imread(f)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    img = preprocess_image(img)
    covid_images.append(img)
    covid_labels.append("CT_COVID")

# Load Non-COVID images
noncovid_images, noncovid_labels = [], []
for f in noncovid_files:
    img = cv2.imread(f)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (224, 224))
    img = preprocess_image(img)
    noncovid_images.append(img)
    noncovid_labels.append("CT_NonCOVID")

# Normalize
covid_images = np.array(covid_images) / 255.0
noncovid_images = np.array(noncovid_images) / 255.0

# Merge datasets
X = np.concatenate((covid_images, noncovid_images), axis=0)
y = np.concatenate((covid_labels, noncovid_labels), axis=0)

# Encode labels
le = LabelEncoder()
y_encoded = le.fit_transform(y)       # convert text labels to 0/1
y_bin = to_categorical(y_encoded, 2)  # one-hot encode

print("Final dataset:", X.shape, y_bin.shape)

# --- Function: Build Modified VGG19 ---
def build_modified_vgg19():
    base_model = VGG19(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

    # Custom head
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    outputs = Dense(2, activation="softmax")(x)

    model = Model(inputs=base_model.input, outputs=outputs)

    # Freeze base model layers
    for layer in base_model.layers:
        layer.trainable = False

    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    return model

# --- Cross-validation ---
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
fold_no = 1
all_fold_acc = []
all_histories = []

for train_idx, val_idx in skf.split(X, y):
    print(f"\n### Training Fold {fold_no}/{n_splits} ###")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y_bin[train_idx], y_bin[val_idx]

    # Data augmentation
    train_aug = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True
    )
    train_gen = train_aug.flow(X_train, y_train, batch_size=batch_size, shuffle=True)

    # Build modified model
    model = build_modified_vgg19()

    steps_per_epoch = len(X_train) // batch_size

    history = model.fit(
        train_gen,
        validation_data=(X_val, y_val),
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        verbose=1
    )

    all_histories.append(history.history)

    # Evaluate
    scores = model.evaluate(X_val, y_val, verbose=0)
    print(f"Fold {fold_no} Accuracy: {scores[1]*100:.2f}%")
    all_fold_acc.append(scores[1])

    # Classification report
    y_pred = model.predict(X_val, batch_size=batch_size)
    y_pred_bin = np.argmax(y_pred, axis=1)
    y_val_bin = np.argmax(y_val, axis=1)
    print(classification_report(y_val_bin, y_pred_bin))

    # Plot per-fold accuracy/loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train')
    plt.plot(history.history['val_accuracy'], label='Validation')
    plt.title(f'Fold {fold_no} - Accuracy')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title(f'Fold {fold_no} - Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
    plt.show()

    fold_no += 1

# --- Summary across folds ---
print("\n=== Cross-validation Results ===")
print("Accuracies per fold:", [round(a*100, 2) for a in all_fold_acc])
print("Mean Accuracy: %.2f%% (+/- %.2f%%)" % (np.mean(all_fold_acc)*100, np.std(all_fold_acc)*100))

# Averaged curves
epochs_range = range(1, epochs+1)
mean_acc = np.mean([h['accuracy'] for h in all_histories], axis=0)
mean_val_acc = np.mean([h['val_accuracy'] for h in all_histories], axis=0)
mean_loss = np.mean([h['loss'] for h in all_histories], axis=0)
mean_val_loss = np.mean([h['val_loss'] for h in all_histories], axis=0)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, mean_acc, label='Train (avg)')
plt.plot(epochs_range, mean_val_acc, label='Validation (avg)')
plt.title('Average Accuracy Across Folds')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, mean_loss, label='Train (avg)')
plt.plot(epochs_range, mean_val_loss, label='Validation (avg)')
plt.title('Average Loss Across Folds')
plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
plt.show()

print("# Save the model to use it for prediction in future")
model.save('mvgg19.h5')

# End time
print("End Time =", datetime.now())
# Out:
# Start Time = 2025-09-09 22:09:07.674153
# COVID images: 400
# Non-COVID images: 399
# Final dataset: (799, 224, 224, 3) (799, 2)
#
# ### Training Fold 1/10 ###
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 28s 792ms/step - accuracy: 0.5920 - loss: 1.0540 - val_accuracy: 0.8125 - val_loss: 0.6095
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8125 - loss: 0.7214 - val_accuracy: 0.8000 - val_loss: 0.6069
# Epoch 3/50
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.8338 - loss: 0.4426 - val_accuracy: 0.8000 - val_loss: 0.5687
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 0.5819 - val_accuracy: 0.8000 - val_loss: 0.5663
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - accuracy: 0.8377 - loss: 0.4338 - val_accuracy: 0.7875 - val_loss: 0.5311
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.4088 - val_accuracy: 0.8000 - val_loss: 0.5262
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - accuracy: 0.8990 - loss: 0.2903 - val_accuracy: 0.8375 - val_loss: 0.4963
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8125 - loss: 0.3576 - val_accuracy: 0.8250 - val_loss: 0.4967
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - accuracy: 0.9002 - loss: 0.3177 - val_accuracy: 0.7500 - val_loss: 0.5039
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8750 - loss: 0.3215 - val_accuracy: 0.7750 - val_loss: 0.4992
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.9119 - loss: 0.2333 - val_accuracy: 0.7375 - val_loss: 0.4957
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8438 - loss: 0.3758 - val_accuracy: 0.7375 - val_loss: 0.5020
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - accuracy: 0.8897 - loss: 0.3127 - val_accuracy: 0.8875 - val_loss: 0.4016
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9062 - loss: 0.2463 - val_accuracy: 0.9125 - val_loss: 0.3961
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 314ms/step - accuracy: 0.9024 - loss: 0.2867 - val_accuracy: 0.6375 - val_loss: 0.6232
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8667 - loss: 0.6177 - val_accuracy: 0.6125 - val_loss: 0.6622
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.8904 - loss: 0.2760 - val_accuracy: 0.7375 - val_loss: 0.4940
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0