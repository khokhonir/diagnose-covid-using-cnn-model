# %% [markdown]
# # New Section

# %%
#Import Necessary Libraries
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import keras
from keras.utils.np_utils import to_categorical
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.layers import  Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import VGG16
#from keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
#import keras_preprocessing
# !pip install Keras-Preprocessing
from keras_preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras_preprocessing.image import ImageDataGenerator
from keras import callbacks
import matplotlib.pyplot as plt
#from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

#Split Into Train Data & Test Data

disease_types=['COVID', 'non-COVID']
data_dir = '/home'
train_dir = os.path.join(data_dir)

train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

IMAGE_SIZE = 150
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
X_Train = X_train / 255.
print(X_Train.shape)


Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.1)


vgg16_model = VGG16(weights = 'imagenet', include_top = False,input_shape=(150,150,3))
x = vgg16_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

predictions = Dense(2, activation = 'softmax')(x)
model = Model(vgg16_model.input,predictions)
for layer in vgg16_model.layers:
    layer.trainable = False
optimizer = Adam(lr=0.0002)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model._name = "VGG16_Architecture"
model.summary()

#Train the Model

annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.70, patience=5, verbose=1, min_lr=1e-4)

BATCH_SIZE = 64
EPOCHS = 30
SIZE=64
N_ch=3

training_datagen = ImageDataGenerator(rotation_range=40,
                        width_shift_range=0.2,
                        height_shift_range=0.2,
                        zoom_range=0.2,
                        horizontal_flip=True,
                        vertical_flip=True,
                        shear_range=0.2)

train_generator = training_datagen.flow(
	X_train, Y_train,
batch_size=64
)
training_datagen.fit(X_train)

filepath="VGG16_Model.hdf5"
checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss',save_best_only=True, mode='min',verbose=1)
callbacks_list = [checkpoint]

#history = model.fit_generator(train_generator, steps_per_epoch=32, epochs=10,
#                              validation_data=(X_val, Y_val),validation_steps=50,callbacks=callbacks_list)
datagen = ImageDataGenerator(rotation_range=360,
                        width_shift_range=0.2,
                        height_shift_range=0.2,
                        zoom_range=0.2,
                        horizontal_flip=True,
                        vertical_flip=True)

datagen.fit(X_train)

history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))

#Plot the Results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('TraiN & Val Acc VS Epochs')
plt.legend(loc=0)
plt.figure()
plt.show()

epochs = range(len(acc))
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('TraiN & Val Loss VS Epochs')
plt.legend(loc=0)
plt.figure()
plt.show()

model.load_weights("VGG16_Model.hdf5")
score = model.evaluate(X_val, Y_val ,verbose=1)
print('Test Loss:', score[0])


Y_pred = model.predict(X_val)
Y_predx = np.argmax(Y_pred, axis = -1)
Y_valx = np.argmax(Y_val, axis = -1)
cf_matrix = confusion_matrix(Y_valx, Y_predx)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, fmt = '')
plt.title("Confusion Matrix")


cfmatrix = confusion_matrix(Y_valx, Y_predx)
precision = precision_score(Y_valx, Y_predx)
recall = recall_score(Y_valx, Y_predx)
f1score = f1_score(Y_valx, Y_predx)

print('Test accuracy:', score[1]*100)
print(f"Confusion Score = {cfmatrix}")
print(f"Precision = {precision}")
print(f"Recall = {recall}")
print(f"F1 Score = {f1score}")
# Out:
# Collecting Keras-Preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 897.9 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.16.0)
# Installing collected packages: Keras-Preprocessing
# Successfully installed Keras-Preprocessing-1.1.2
# 1659it [00:10, 162.88it/s]
# (1659, 150, 150, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "VGG16_Architecture"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 14,849,602
# Trainable params: 133,378
# Non-trainable params: 14,716,224
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# <ipython-input-1-9bd39057b612>:127: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
# Epoch 1/30
# 23/23 [==============================] - ETA: 0s - loss: 1.0205 - accuracy: 0.5269
# Epoch 1: val_loss improved from inf to 0.67113, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 402s 17s/step - loss: 1.0205 - accuracy: 0.5269 - val_loss: 0.6711 - val_accuracy: 0.7108 - lr: 2.0000e-04
# Epoch 2/30
# 23/23 [==============================] - ETA: 0s - loss: 0.9259 - accuracy: 0.5577
# Epoch 2: val_loss did not improve from 0.67113
# 23/23 [==============================] - 389s 17s/step - loss: 0.9259 - accuracy: 0.5577 - val_loss: 0.6776 - val_accuracy: 0.6988 - lr: 2.0000e-04
# Epoch 3/30
# 23/23 [==============================] - ETA: 0s - loss: 0.8485 - accuracy: 0.6039
# Epoch 3: val_loss improved from 0.67113 to 0.66247, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 376s 16s/step - loss: 0.8485 - accuracy: 0.6039 - val_loss: 0.6625 - val_accuracy: 0.7470 - lr: 2.0000e-04
# Epoch 4/30
# 23/23 [==============================] - ETA: 0s - loss: 0.8321 - accuracy: 0.6137
# Epoch 4: val_loss improved from 0.66247 to 0.63944, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 375s 16s/step - loss: 0.8321 - accuracy: 0.6137 - val_loss: 0.6394 - val_accuracy: 0.7349 - lr: 2.0000e-04
# Epoch 5/30
# 23/23 [==============================] - ETA: 0s - loss: 0.7989 - accuracy: 0.6325
# Epoch 5: val_loss improved from 0.63944 to 0.61867, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 393s 17s/step - loss: 0.7989 - accuracy: 0.6325 - val_loss: 0.6187 - val_accuracy: 0.7470 - lr: 2.0000e-04
# Epoch 6/30
# 23/23 [==============================] - ETA: 0s - loss: 0.7535 - accuracy: 0.6760
# Epoch 6: val_loss improved from 0.61867 to 0.60743, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 384s 17s/step - loss: 0.7535 - accuracy: 0.6760 - val_loss: 0.6074 - val_accuracy: 0.7590 - lr: 2.0000e-04
# Epoch 7/30
# 23/23 [==============================] - ETA: 0s - loss: 0.7189 - accuracy: 0.6732
# Epoch 7: val_loss improved from 0.60743 to 0.58970, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 384s 17s/step - loss: 0.7189 - accuracy: 0.6732 - val_loss: 0.5897 - val_accuracy: 0.7711 - lr: 2.0000e-04
# Epoch 8/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.6956
# Epoch 8: val_loss improved from 0.58970 to 0.57567, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 385s 17s/step - loss: 0.6911 - accuracy: 0.6956 - val_loss: 0.5757 - val_accuracy: 0.7892 - lr: 2.0000e-04
# Epoch 9/30
# 23/23 [==============================] - ETA: 0s - loss: 0.7077 - accuracy: 0.6872
# Epoch 9: val_loss improved from 0.57567 to 0.56609, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 384s 17s/step - loss: 0.7077 - accuracy: 0.6872 - val_loss: 0.5661 - val_accuracy: 0.7892 - lr: 2.0000e-04
# Epoch 10/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.7061
# Epoch 10: val_loss improved from 0.56609 to 0.56156, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 384s 17s/step - loss: 0.6796 - accuracy: 0.7061 - val_loss: 0.5616 - val_accuracy: 0.8012 - lr: 2.0000e-04
# Epoch 11/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.7145
# Epoch 11: val_loss improved from 0.56156 to 0.55121, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 384s 17s/step - loss: 0.6618 - accuracy: 0.7145 - val_loss: 0.5512 - val_accuracy: 0.8253 - lr: 2.0000e-04
# Epoch 12/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.7285
# Epoch 12: val_loss improved from 0.55121 to 0.53192, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 383s 17s/step - loss: 0.6483 - accuracy: 0.7285 - val_loss: 0.5319 - val_accuracy: 0.8193 - lr: 2.0000e-04
# Epoch 13/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6403 - accuracy: 0.7390
# Epoch 13: val_loss improved from 0.53192 to 0.50578, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 371s 16s/step - loss: 0.6403 - accuracy: 0.7390 - val_loss: 0.5058 - val_accuracy: 0.8193 - lr: 2.0000e-04
# Epoch 14/30
# 23/23 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.7348
# Epoch 14: val_loss improved from 0.50578 to 0.48837, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 372s 16s/step - loss: 0.6262 - accuracy: 0.7348 - val_loss: 0.4884 - val_accuracy: 0.8133 - lr: 2.0000e-04
# Epoch 15/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5924 - accuracy: 0.7516
# Epoch 15: val_loss improved from 0.48837 to 0.47383, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 373s 16s/step - loss: 0.5924 - accuracy: 0.7516 - val_loss: 0.4738 - val_accuracy: 0.8072 - lr: 2.0000e-04
# Epoch 16/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5852 - accuracy: 0.7537
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00013999999646330252.
#
# Epoch 16: val_loss improved from 0.47383 to 0.47028, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 373s 16s/step - loss: 0.5852 - accuracy: 0.7537 - val_loss: 0.4703 - val_accuracy: 0.8072 - lr: 2.0000e-04
# Epoch 17/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.7579
# Epoch 17: val_loss improved from 0.47028 to 0.46520, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 372s 16s/step - loss: 0.5787 - accuracy: 0.7579 - val_loss: 0.4652 - val_accuracy: 0.8193 - lr: 1.4000e-04
# Epoch 18/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5581 - accuracy: 0.7691
# Epoch 18: val_loss improved from 0.46520 to 0.45308, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 363s 16s/step - loss: 0.5581 - accuracy: 0.7691 - val_loss: 0.4531 - val_accuracy: 0.8193 - lr: 1.4000e-04
# Epoch 19/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5776 - accuracy: 0.7474
# Epoch 19: val_loss improved from 0.45308 to 0.44376, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 363s 16s/step - loss: 0.5776 - accuracy: 0.7474 - val_loss: 0.4438 - val_accuracy: 0.8133 - lr: 1.4000e-04
# Epoch 20/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5666 - accuracy: 0.7607
# Epoch 20: val_loss improved from 0.44376 to 0.43525, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 372s 16s/step - loss: 0.5666 - accuracy: 0.7607 - val_loss: 0.4352 - val_accuracy: 0.8133 - lr: 1.4000e-04
# Epoch 21/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5473 - accuracy: 0.7733
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 21: val_loss improved from 0.43525 to 0.43168, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 371s 16s/step - loss: 0.5473 - accuracy: 0.7733 - val_loss: 0.4317 - val_accuracy: 0.8133 - lr: 1.4000e-04
# Epoch 22/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5388 - accuracy: 0.7873
# Epoch 22: val_loss improved from 0.43168 to 0.42502, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 370s 16s/step - loss: 0.5388 - accuracy: 0.7873 - val_loss: 0.4250 - val_accuracy: 0.8133 - lr: 1.0000e-04
# Epoch 23/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.7677
# Epoch 23: val_loss improved from 0.42502 to 0.41799, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 371s 16s/step - loss: 0.5451 - accuracy: 0.7677 - val_loss: 0.4180 - val_accuracy: 0.8012 - lr: 1.0000e-04
# Epoch 24/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5527 - accuracy: 0.7747
# Epoch 24: val_loss improved from 0.41799 to 0.41040, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 380s 17s/step - loss: 0.5527 - accuracy: 0.7747 - val_loss: 0.4104 - val_accuracy: 0.8072 - lr: 1.0000e-04
# Epoch 25/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5281 - accuracy: 0.7817
# Epoch 25: val_loss improved from 0.41040 to 0.40520, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 372s 16s/step - loss: 0.5281 - accuracy: 0.7817 - val_loss: 0.4052 - val_accuracy: 0.8133 - lr: 1.0000e-04
# Epoch 26/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.7915
# Epoch 26: val_loss improved from 0.40520 to 0.40224, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 374s 16s/step - loss: 0.5171 - accuracy: 0.7915 - val_loss: 0.4022 - val_accuracy: 0.8072 - lr: 1.0000e-04
# Epoch 27/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.7740
# Epoch 27: val_loss improved from 0.40224 to 0.39862, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 378s 16s/step - loss: 0.5214 - accuracy: 0.7740 - val_loss: 0.3986 - val_accuracy: 0.8253 - lr: 1.0000e-04
# Epoch 28/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5077 - accuracy: 0.7929
# Epoch 28: val_loss improved from 0.39862 to 0.39349, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 375s 16s/step - loss: 0.5077 - accuracy: 0.7929 - val_loss: 0.3935 - val_accuracy: 0.8373 - lr: 1.0000e-04
# Epoch 29/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.7761
# Epoch 29: val_loss improved from 0.39349 to 0.38965, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 376s 16s/step - loss: 0.5238 - accuracy: 0.7761 - val_loss: 0.3897 - val_accuracy: 0.8373 - lr: 1.0000e-04
# Epoch 30/30
# 23/23 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.7712
# Epoch 30: val_loss improved from 0.38965 to 0.38448, saving model to VGG16_Model.hdf5
# 23/23 [==============================] - 378s 17s/step - loss: 0.5224 - accuracy: 0.7712 - val_loss: 0.3845 - val_accuracy: 0.8434 - lr: 1.0000e-04
# 6/6 [==============================] - 38s 6s/step - loss: 0.3845 - accuracy: 0.8434
# Test Loss: 0.38447675108909607
# 6/6 [==============================] - 39s 6s/step
# Test accuracy: 84.33734774589539
# Confusion Score = [[ 26  18]
#  [  8 114]]
# Precision = 0.8636363636363636
# Recall = 0.9344262295081968
# F1 Score = 0.8976377952755905
